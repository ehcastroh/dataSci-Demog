# %% [markdown]
# ##  Outline
#
# 1. Undocumentedness - and legislation
#     1. Vargas
# 1. Diversity - and legislation
# 1. In class exercise - measuring diversity

# %% [markdown]
# ### Undocumentedness
# 1. Reed-Johnson 1924 - First numerical limits on immigrations
#     1. ==> First time otherwise identical people can be allowed OR denied
#     1. Before R-J
#         1. Likely to become public charge
#         1. Loathesome disease
#         1. foolish enough to admit to being an Anarchist
#         1. Literacy test
#         1. Chinese exclusion (1882) + Asian barred zone (1917)
#     1. Naturalization Laws and immigration laws are distinct
#         1. 1795 - 1865  "Free and white" ; after 1865-1945 + African decent ;1945-1953 + Chinese, Indian, Fillipino; 1953 no race bars
#         1. Cateogory of legal immigrants ineligible for citizenship exists until 1953
#
# 1. Reed-Johnson (1924) + McCarran-Walter (1953) DO NOT LIMIT immigration from "Independent Western Hemisphere Nations"
#     1. Western Agricultural interests
#     1. Cold War - need to be on good terms with neighbors
#     1. Reciprocity - US business wanted access to markets
# 1. Bracero Program 1942-1963
#     1. Replaced less formal agreement in WWI
#     1. Allowed Mexican laborers to work in US under "negotiated" conditions
#     1. Why was this needed given lack of numerical quotas ?
#         1. "Adminstirative" limitations
#         1. Discomfort with hypocracy
# 1.  Hart-Cellar 1965
#     1. eliminated nationalities quota system in favor of family ties + skills
#     1. Imposed 120K limit on Western Hemisphere ; 1976 (added 20K limit per country)
#         1. ==> HUGE effect on undocumentedness
# 1. Immigration Reform and Control Act (IRCA) 1986
#     1. "Three legged stool"
#         1. Border Security
#         1. Amnesty
#         1. Employer sanctions

# %% [markdown]
# ## Diversity -- post Reed-Johnson (1924)
# ### lines blur between previously distinct groups of "whites"
# >..Originally settled  almost exclusively by Nordics,  was toward the close of the nineteenth century invaded by hordes of immigrant Alpines and Mediterraneans, not to mention Asiatics elements like Levantines and Jews.  As a result, the Nordic native American has been crowded out with amazing rapidity by the swarming, prolific aliens ... The melting-pot may mix, but it does not melt.  Each race-type, formed ages ago is a stubbornly persistent entity.  Each type possesses a special set of characters:  not merely the physical characters visible to the naked eye, but moral intellectual, and spiritual as well.
#
# --Lothrop Stoddard 1920 in Rising Tide of  Color against White Supremacy
#
# ### 7 years later
# >“...most of the immigrant stocks are racially not too remote for ultimate assimilation..But what is thus true of European immigrants, most of whom belong to some branch of the white racial group, most emphatically does not apply to non-white immigrants, like the Chinese, Japanese, or Mexicans; neither does it apply to the large resident Negro element... Here, ethnic differences are so great that 'assimilation' in the racial sense is impossible
#
# --Lothrop Stoddard 1927 in Reforging America
#    (cited in Jacobsen 1998)
#
# ### by 1941 ..
# <img src="http://courses.demog.berkeley.edu/mason88/images/libertyChildren.jpg" width="400">
#
# ## Lines also blur between different groups of Blacks
#
# ### 1890 Instructions for Census Enumerators
#
# > 4. Whether white, black, mulatto. quadroon, octoroon, Chinese, Japanese, or Indian.
#
# > Write white, black, mulatto, quadroon, octoroon, Chinese, Japanese, or Indian, according to the color or race of the person enumerated. Be particularly careful to distinguish between blacks, mulattos, quadroons, and octoroons. The word "black" should be used to describe those persons who have three-fourths or more black blood; "mulatto," those persons who have from three-eighths to five-eighths black blood; "quadroon," those persons who have one-fourth black blood; and "octoroon," those persons who have one-eighth or any trace of black blood.
#
# ### 1930 Instructions for Census Enumerators
# ##### "mulato" category last used in 1920, by 1930 the "one drop rule" rules
#
# > 151. Negroes.-A person of mixed white and Negro blood should be returned as a Negro, no matter how small the percentage of Negro blood. Both black and mulatto persons are to be returned as Negroes, without distinction. A person of mixed Indian and Negro blood should be returned a Negro, unless the Indian blood predominates and the status as an Indian is generally accepted in the community.
#
#
# > 155. Other mixed races.-Any mixture of white and nonwhite should be reported according to the nonwhite parent. Mixtures of colored races should be reported according to the race of the father, except Negro-Indian (see par. 151).
#
# ## But anti semitism and anti Asian sentiments persist as does anti-Mexican bias
#
# <img src="http://courses.demog.berkeley.edu/mason88/images/raceQuestion.png">
#
# > [The Filipino] usually frequents the poorer quarters of out towns and spends the residues of his savings in brothels and dance halls, which in spite of our laws exist to minister to his lower nature.  Everything in our rapid, pleasure-seeking life,  and the more or less shameless exhibitionism which accompanies it, contributes to overwhelm these young men who come, in most cases, only a few years removed from the even placid life of the primitive native of a barrio
#
# --David P. Barrows,<br>
# <b>President of the University of California</b>
# cited in Daniels 2004
#
# ###  The State Department on allowing Jews from eastern Europe to immigrate in 1940
#
# >"We can delay and effectively stop for a temporary period of indefinite length the number of immigrants into the United States. We could do this by simply advising our consuls to put every obstacle in the way and to require additional evidence and to resort to various administrative devices which would postpone and postpone and postpone the granting of the visas."
#
# --Breckenridge Long 1940
# Assistant Secretary of State in charge of Visa Department

# %% [markdown]
# Demography 88<br>
# Fall 2017<br>
# Carl Mason (cmason@berkeley.edu)<br>
# ## Lab 5-ish
#
# ## Exploring population diversity in CA and the US 2000-2014
#
# This is intended to be a short in class exercise exploring the numerical side of diversity.  We have discussed the concept in historical and sociological terms and the role of immigration legislation in (unintentionally) promoting diversity in the late 20th and early 21st Centuries.  In this exercise we'll attempt to quantify diversity and assess its recent trajectory.
#
# Problem 1 is straight forward, Problem 2 is not.

# %%
#Run this cell to import the stuff we'll need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
plt.style.use('fivethirtyeight')

# %matplotlib inline
from datascience import Table
from datascience.predicates import are
from IPython.display import HTML, IFrame, display
datasite="http://courses.demog.berkeley.edu/mason88/data/"
quizsite="http://courses.demog.berkeley.edu/mason88/cgi-bin/quiz.py"
  
def cquiz(qno) : 
    import IPython, requests 
    try:
        sid
    except NameError: 
        print("HEY! did you enter your sid way up at the top of this notebook?")
    Linkit='{0}?qno={1}&sid={2}'.format(quizsite,qno,sid)
    #print(Linkit)
    html = requests.get(Linkit)
    #display(IFrame(Linkit, 1000, 300))
    display(IFrame(Linkit, 1000, 400))


    
######################
# Here it is ... the obvious place to put your student id
sid=""
######################
if sid == "" :
    print("HEY! didn't I tell you to put your sid in the obvious place")

# %%
cquiz('diversity0-partners')

# %%
# Read in some census data
pops=Table().read_table(datasite+"Ca-US-diversity-2014.csv")
pops.show()

# %%
list(poppct)[1:]

# %% [markdown]
# ## Problem 1:
#
# Produce a table of the proportions of each group within
# each population. The resulting table should be the same shape as pops.  element 0,1 should hold
# the proportion of california's population in 2000 who identified as "Hispanic:Asian/PacIsland"
#
# #### Ponder the implications of reporting the Hispanic population disagregated by race

# %%
cquiz('diversity0-0')

# %% [markdown]
# # Problem 2
# ## Develop a diversity statistic and apply it to all 4 columns of the pops table in order to determine:
#
#
#
# 1) Whether the US or California has the more diverse population in 2000 and in 2014.
#
# 2) Whether the difference in diversity between California and the rest of the US grew or shrank between 2000 and 2014.
#
# Please do not simply apply an index that you read about in https://en.wikipedia.org/wiki/Diversity_index UNLES YOU ARE PREPARED to fully explain how and why it works.  The idea of this exercise is to think about how to construct your own statistic.
#
# Consider some of the following issues:
#
# * How would your measure of diversity be affected by merging or separating groups. For example, what would be the effect of merging all of the hispanic categoreis into a single "hispanic" group?  What would be the effect of subdividing the "Three+ major groups" into a "four groups", "five groups", "six groups" ... ?
#
# * How Does population size affect your measure of diversity.  By your measure, is the US population intrinsically  more(or less) diverse than the California population simply because it is larger?
#
# NOTE: Your final project could be a similar exercise  in which you develop a statistic (such as a measure or diversity) and use some tools that you are about to learn in the foundation course, assess your certainty as to whether it differes between two groups or has changed over time.

# %%
cquiz('diversity0-01')
